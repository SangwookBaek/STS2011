# %%
import matplotlib.pyplot as plt
plt.plot([1,4,9,16],'bp-',lw=5,mew=5,mec='g',mfc='r',ms=15)#red, square marker, --dashed 
#line color,marker,line style순으로 적용
plt.show()

# %%
plt.plot([1,4,9,16],)
plt.xlim(-0.5,3.5)
plt.ylim(-1,18)
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x7f1f44900cd0>,
# ...
#  <a list of 3 Text major ticklabel objects>)
