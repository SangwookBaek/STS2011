# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.random.normal(1,1,size=(100,1))
x2 = np.random.normal(-2,4,size = (100,1))

# %%
x = np.concatenate((x1,x2),axis = 1)
x
# Out:
# array([[ 1.14073613e+00,  1.28668896e+00],
#        [ 2.64704101e+00,  6.45383914e-02],
#        [ 1.19313090e+00, -9.02670344e-01],
#        [ 8.77613595e-01,  4.62083309e+00],
#        [ 1.11878362e+00,  2.22820384e-02],
#        [ 5.34414565e-01, -5.99532659e+00],
#        [ 1.83150451e+00, -1.41084477e+00],
#        [ 5.48713410e-01, -1.05323858e+00],
#        [ 3.13176207e+00, -4.72883211e+00],
#        [ 4.23942116e-01, -6.40875871e+00],
#        [ 1.54131380e+00, -7.11687417e+00],
#        [ 1.67545423e+00, -3.58271926e+00],
#        [-6.11733922e-01, -7.06476234e+00],
#        [-5.20157767e-01, -3.18792779e-01],
#        [ 4.79064541e-01, -1.06766853e+00],
#        [ 3.44016729e+00,  1.80557035e+00],
#        [ 2.25323822e+00, -6.90821768e+00],
#        [ 2.34323162e+00, -8.75043131e+00],
#        [ 1.64582011e+00, -1.98053089e-01],
#        [-2.71488667e-01,  5.63860999e-01],
#        [ 1.38320860e+00, -2.95722002e+00],
#        [ 9.81511639e-01,  2.07254747e+00],
#        [ 2.02524255e+00, -6.64844455e+00],
#        [ 6.79626866e-01,  8.13030301e+00],
#        [ 2.16209154e+00, -7.25517384e-01],
#        [ 2.05710340e-01,  4.76008604e+00],
#        [ 2.58971494e+00, -7.42312161e+00],
#        [ 1.23031616e+00, -8.92522511e+00],
#        [ 5.20135633e-01,  3.73847524e+00],
#        [ 1.76070638e+00,  1.17464757e+00],
#        [-1.28371993e+00, -4.49944571e+00],
#        [ 8.53523672e-01,  4.13069309e+00],
#        [ 1.25368582e+00, -8.76354885e+00],
#        [ 2.28861374e-01, -4.81593033e+00],
#        [ 1.88940475e+00, -3.77572822e+00],
#        [ 1.41813811e+00, -6.58652586e+00],
#        [-7.23864218e-01,  1.05115140e+00],
#        [ 3.43508839e-04, -3.38335158e+00],
#        [ 9.48195477e-02, -3.04575466e+00],
#        [ 1.13294246e+00, -6.66112191e+00],
#        [ 7.09660460e-01, -3.81412156e+00],
#        [ 1.71990129e+00,  3.66238066e-01],
#        [ 1.30720314e+00,  1.02020099e+00],
#        [-1.23168860e+00,  7.87829254e+00],
#        [ 2.55535151e+00, -1.76020516e+00],
#        [ 1.04129137e+00,  8.00918177e-01],
#        [ 5.55868198e-01, -1.66773440e+00],
#        [ 2.14185027e+00, -2.59997728e+00],
#        [ 3.47230302e-01,  6.81423546e-02],
#        [ 5.00684049e-01, -5.33958792e-01],
#        [ 1.89898774e+00, -2.45340373e+00],
#        [-5.13005640e-01, -8.38464410e+00],
#        [ 1.64435780e+00, -2.32973419e+00],
#        [ 8.43668094e-01, -2.54121020e+00],
#        [ 1.77330955e+00,  2.56009583e+00],
#        [ 1.37733697e+00, -1.31640298e+00],
#        [ 1.83983570e+00,  2.26326602e+00],
#        [ 7.18138880e-01,  8.96989469e-01],
#        [ 1.92760582e+00, -4.92466313e+00],
#        [ 2.55026103e+00,  4.16960825e+00],
#        [ 7.19602713e-01, -2.18847407e-01],
#        [ 7.06200084e-01,  4.32094911e+00],
#        [ 1.19842807e+00, -2.09705095e+00],
#        [ 7.76590639e-01, -7.94632250e+00],
#        [-1.06009076e+00, -6.91232934e+00],
#        [ 1.54047705e+00, -4.44242191e+00],
#        [ 1.71546930e+00,  1.10232284e+00],
#        [ 1.74887132e-01, -1.08603698e+00],
#        [ 1.32196531e+00, -6.68331001e+00],
#        [ 3.19203976e-01,  6.78735002e-01],
#        [ 6.11040911e-01, -4.02062355e+00],
#        [ 4.53629478e-01, -8.88602025e+00],
#        [-5.58092344e-01,  3.62248970e+00],
#        [-1.03941418e+00, -2.30006412e-01],
#        [ 2.73576837e+00, -4.43161563e+00],
#        [-5.89144142e-01, -2.69957011e+00],
#        [ 1.49977483e+00,  1.03143193e+00],
#        [ 2.04508136e+00, -5.28644574e+00],
#        [ 2.37527841e+00, -7.47644711e+00],
#        [ 2.14409104e+00, -3.24440581e+00],
#        [ 7.27983510e-01, -2.63737744e+00],
#        [-5.44858749e-01, -1.27546307e+00],
#        [-1.77377276e-01, -4.61326572e+00],
#        [ 7.17993935e-01, -5.09531089e+00],
#        [ 1.59272283e+00, -1.01996023e+01],
#        [ 2.50041497e+00, -5.04584142e+00],
#        [ 7.04087537e-01, -3.42061078e+00],
#        [ 3.90231061e-01, -3.08693826e+00],
#        [ 7.84909337e-01, -6.06800565e+00],
#        [ 5.14664119e-01, -6.47743619e+00],
#        [ 1.50337651e+00,  2.60552310e+00],
#        [ 2.37386630e+00, -6.07901546e+00],
#        [ 4.96170453e-01, -1.48375687e+00],
#        [ 7.02548498e-01,  1.70000323e-01],
#        [ 1.59093372e+00, -1.19774807e+00],
#        [ 5.19315422e-01,  3.18077557e-01],
#        [ 1.46339698e+00, -1.84235061e-01],
#        [ 1.52041113e+00,  1.90790609e+00],
#        [ 2.84778634e-01, -1.88114817e+00],
#        [ 1.23779451e+00,  1.65897243e+00]])

# %%
df3 = pd.DataFrame(x,columns = ["x1","x2"])
df3
# Out:
#           x1        x2
# 0   1.140736  1.286689
# 1   2.647041  0.064538
# 2   1.193131 -0.902670
# 3   0.877614  4.620833
# 4   1.118784  0.022282
# ..       ...       ...
# 95  0.519315  0.318078
# 96  1.463397 -0.184235
# 97  1.520411  1.907906
# 98  0.284779 -1.881148
# 99  1.237795  1.658972
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3["x1"],df3["x2"])

# %%
s3 = pd.Series(np.random.normal(0,1,size=200))

# %%
s3.hist(facecolor="r",alpha= 0.4)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.random.random((100,100))
plt.imshow(a)
plt.colorbar()

# %%
import matplotlib.image as mpimg
img = mpimg.imread("icebear.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()
